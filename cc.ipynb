# %% [markdown]
# # An Introduction to Seaborn

# %% [markdown]
# Seaborn is a data visualization tool based on Python library, matplotlib.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
df = datasets.load_iris(as_frame=True).data
df["class"] = datasets.load_iris(as_frame=True).target.replace([0, 1, 2], ['setosa', 'versicolor', 'virginica'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     class
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## Histogram

# %%
sns.set_style("dark")
sns.histplot(x = df["sepal length (cm)"])
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(y = df["sepal length (cm)"])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='sepal length (cm)'>

# %%
sns.histplot(x = df["sepal length (cm)"], hue = df["class"], multiple = "stack")
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(x = df["sepal length (cm)"], hue = df["class"], multiple = "dodge")
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Count'>

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(x = df["sepal length (cm)"], y = df["sepal width (cm)"])
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
sns.scatterplot(x = df["sepal length (cm)"], y = df["sepal width (cm)"], hue = df["class"])
plt.legend(loc = "upper right")

# %%
sns.pairplot(df, hue = "class")

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x = "class", y = "sepal length (cm)", data = df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal length (cm)'>

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x = "class", y = "sepal length (cm)", data = df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal length (cm)'>

# %% [markdown]
# ## Bar chart

# %%
df_2 = sns.load_dataset("penguins")
sns.countplot(df_2.species)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
grid = sns.FacetGrid(col = "sex", data = df_2)
grid.map(sns.countplot, "species")

# %%
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]
